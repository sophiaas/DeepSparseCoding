# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.display import IFrame
from IPython.display import Image
import utils.rd_plot_functions as pf                                               
sns.set_style('white')

# %% [markdown]
# # Evaluating training

# %%
batch_params = {
    "model_type": 'lca',
    "n_neurons": [256],
    "costs": ['l0'],
    "lams": ['0.3'],
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}

# %%
max_batch = pf.batch_plot_model_grads(batch_params)
max_batch = pf.batch_plot_model_loss(batch_params)
pf.print_model_sched(batch_params, True)
# Out:
# lca_256_l0_0.3_v2.0:
# [{'num_steps': 100, 'sparse_mult': 0.3, 'num_batches': 35000, 'decay_rate': [0.8], 'decay_steps': [5000], 'weight_lr': [0.2], 'weights': ['phi'], 'staircase': [True]}]
# {'thresh_type': 'l0', 'log_to_file': True, 'data_type': 'vanhateren', 'device': '/gpu:1', 'data_dir': '/media/tbell/datasets', 'norm_weights': True, 'model_type': 'lca', 'patch_edge_size': 16, 'cp_int': 10000, 'tau': 0.03, 'input_shape': [256], 'max_cp_to_keep': 2, 'cp_load_step': 150000, 'cp_load_var': ['phi'], 'num_pixels': 256, 'vectorize_images': True, 'cp_load': False, 'num_neurons': 256, 'eps': 1e-12, 'norm_images': False, 'base_dir': '/media/tbell/sanborn/rd_analysis/', 'gen_plot_int': 1000, 'overlapping_patches': True, 'version': '2.0', 'optimizer': 'annealed_sgd', 'cp_load_name': 'pretrain_mnist', 'rectify_a': True, 'extract_patches': True, 'patch_variance_threshold': 1e-06, 'save_plots': True, 'cp_load_ver': '0.0', 'input_dir': '/media/tbell/sanborn/rd_analysis/inputs/train_nowht.npz', 'log_int': 100, 'out_dir': '/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/', 'randomize_patches': True, 'num_steps': 100, 'cp_dir': '/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/lca_256_l0_0.3_v2.0/checkpoints/', 'contrast_normalize': False, 'model_name': 'lca_256_l0_0.3', 'rand_seed': 1234567890, 'batch_size': 100, 'num_images': 50, 'num_patches': 100000.0, 'dt': 0.001}

# %% [markdown]
# # View model bases / recons

# %% [markdown]
# ## During training

# %%
model_name = 'lca_256_l0_0.3_v2.0'
batch = str(round(max_batch, -3))
if len(batch) < 5:
    batch = '0'+ batch

# %% [markdown]
# ### bases

# %%
Image(batch_params["out_dir"]+model_name+"/vis/phi_"+batch_params['version']+"_"+batch+".png")

# %% [markdown]
# ### recons

# %%
Image(batch_params["out_dir"]+model_name+"/vis/recons_"+batch_params["version"]+"-"+batch+".png")
