# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.display import IFrame
from IPython.display import Image
import utils.rd_plot_functions as pf                                               
sns.set_style('white')

# %% [markdown]
# # Evaluating training

# %%
batch_params = {
    "model_type": 'lca',
    "n_neurons": [512],
    "costs": ['l0'],
    "lams": ['0.3'],
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}

# %%
max_batch = pf.batch_plot_model_grads(batch_params)
max_batch = pf.batch_plot_model_loss(batch_params)
max_batch = pf.batch_plot_activity(batch_params)
pf.print_model_sched(batch_params, True)
# Out:
# lca_512_l0_0.3_v2.0:
# [{'decay_rate': [0.8], 'sparse_mult': 0.3, 'weights': ['phi'], 'decay_steps': [5000], 'weight_lr': [0.2], 'num_batches': 35000, 'staircase': [True], 'num_steps': 100}]
# ...

# %% [markdown]
# # View model bases / recons

# %% [markdown]
# ## During training

# %%
model_name = 'lca_256_l0_0.3_v2.0'
batch = str(round(max_batch, -3))
if len(batch) < 5:
    batch = '0'+ batch

# %% [markdown]
# ### bases

# %%
Image(batch_params["out_dir"]+model_name+"/vis/phi_"+batch_params['version']+"_"+"35000"+".png")

# %% [markdown]
# ### recons

# %%
Image(batch_params["out_dir"]+model_name+"/vis/recons_"+batch_params["version"]+"-"+batch+".png")
