# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import IFrame
from IPython.display import Image
import utils.rd_plot_functions as pf  
import numpy as np
import utils.log_parser as lp
sns.set_style('white')

# %% [markdown]
# # Evaluating training

# %%
batch_params = {
    "model_type": 'lca',
    "n_neurons": [256],
    "costs": ['l0'],
    "lams": ['1'],
    "version": 'v9.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/lca_lpf/" 
}

# %%
max_batch = pf.batch_plot_model_grads(batch_params)
max_batch = pf.batch_plot_model_loss(batch_params)
max_batch = pf.batch_plot_activity(batch_params)
pf.print_model_sched(batch_params, True)
# Out:
# nan
# lca_256_l0_1_v9.0:
# [{'staircase': [True], 'num_steps': 40, 'weights': ['phi'], 'decay_rate': [0.8], 'decay_steps': [2500], 'weight_lr': [0.25], 'sparse_mult': 1, 'num_batches': 1000000}]
# ...

# %% [markdown]
# # View model bases / recons

# %% [markdown]
# ## During training

# %%
model_name = 'lca_256_l0_1_v8.0'
# model_name='ica_v1.0'
batch = str(max_batch - (max_batch%1000))
if len(batch) < 5:
    batch = '0'+ batch
batch='01000'

# %% [markdown]
# ### bases

# %%
Image(batch_params["out_dir"]+model_name+"/vis/phi_"+batch_params['version']+"_"+batch+".png")

# %%
Image("/media/tbell/sanborn/rd_analysis/outputs/ica/ica_v1.0/vis/a_v1.0-1000000.png")

# %% [markdown]
# ### recons

# %%
Image(batch_params["out_dir"]+model_name+"/vis/recons_"+batch_params["version"]+"-"+batch+".png")

# %%
Image(batch_params["out_dir"]+model_name+"/vis/images_"+batch_params["version"]+"-"+batch+".png")
