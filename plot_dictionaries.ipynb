# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os                                                                       
import numpy as np    
import pandas as pd
import pickle
from IPython.display import Image
import utils.plot_functions as pf

# %% [markdown]
# # 1X | cost = l0 | lambda = 0.1

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 256,
    "cost": 'l0',
    "lam": '0.1',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 1X | cost = l0 | lambda = 0.2

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 256,
    "cost": 'l0',
    "lam": '0.2',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 1X | cost = l0 | lambda = 0.3

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 256,
    "cost": 'l0',
    "lam": '0.3',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 1X | cost = l0 | lambda = 0.4

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 256,
    "cost": 'l0',
    "lam": '0.4',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 1X | cost = l0 | lambda = 0.5

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 256,
    "cost": 'l0',
    "lam": '0.5',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 2X | cost = l0 | lambda = 0.1

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 512,
    "cost": 'l0',
    "lam": '0.1',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 2X | cost = l0 | lambda = 0.2

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 512,
    "cost": 'l0',
    "lam": '0.2',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 2X | cost = l0 | lambda = 0.3

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 512,
    "cost": 'l0',
    "lam": '0.3',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 2X | cost = l0 | lambda = 0.4

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 512,
    "cost": 'l0',
    "lam": '0.4',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %% [markdown]
# # 2X | cost = l0 | lambda = 0.5

# %%
params  = {
    "model_type": 'lca',
    "n_neurons": 512,
    "cost": 'l0',
    "lam": '0.5',
    "version": 'v2.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/nowht_v3/" 
}
params['mod_label'] = params['model_type']+'_'+str(params['n_neurons'])+'_'+params['cost']+'_'+params['lam']+'_'+params['version']
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
Image(params["out_dir"]+params['mod_label']+"/vis/phi_"+params['version']+"_"+batch+".png")

# %%
params  = {
    "model_type": 'ica',
    "version": 'v1.0',
    "out_dir": "/media/tbell/sanborn/rd_analysis/outputs/ica/ica_v1.0" 
}
batch ='35000'
if len(batch) < 5:
    batch = '0'+batch
    
Image("/media/tbell/sanborn/rd_analysis/outputs/ica/ica_v1.0/vis/a_v1.0-35000.png")
