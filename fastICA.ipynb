# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline

import numpy as np
import tensorflow as tf
import json as js
import params.param_picker as pp
import models.model_picker as mp
from sklearn.decomposition import FastICA
import matplotlib.pyplot as plt
import utils.plot_functions as pf
import sklearn.decomposition
import pickle

# %%
input_dir = "/media/tbell/sanborn/rd_analysis/inputs/vh_test_ftwhite.npz"

# %%
weights_dir = "/media/tbell/sanborn/rd_analysis/outputs/fastica/weights_v8.p"

# %%
with open(weights_dir, 'rb') as handle:
    weights = pickle.load(handle)

# %%
np.min(weights)
# Out:
# -0.37612925129703711

# %%
weights /= np.std(weights)

# %%
pf.plot_bases(weights.T)

# %%
with np.load(input_dir) as d:
    data = d['arr_0'].item()

# %%
ica_mod = FastICA(whiten=False, tol=.1)

# %%
ica_mod.fit(data['train'].images)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a363fece1e2b> in <module>()
# ----> 1 ica_mod.fit(data['train'].images)
#
# ~/virtual_envs/py3/lib/python3.4/site-packages/sklearn/decomposition/fastica_.py in fit(self, X, y)
#     533         self
#     534         """
# --> 535         self._fit(X, compute_sources=False)
#     536         return self
#     537
#
# ~/virtual_envs/py3/lib/python3.4/site-packages/sklearn/decomposition/fastica_.py in _fit(self, X, compute_sources)
#     485             max_iter=self.max_iter, tol=self.tol, w_init=self.w_init,
#     486             random_state=self.random_state, return_X_mean=True,
# --> 487             compute_sources=compute_sources, return_n_iter=True)
#     488
#     489         if self.whiten:
#
# ...

# %%
pf.plot_bases(ica_mod.components_)

# %%
sklearn.decomposition.fastica(data['train'].images, whiten=False)
# Out:
# /home/sanborn/virtual_envs/py3/lib/python3.4/site-packages/sklearn/decomposition/fastica_.py:118: UserWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# (None, array([[-0.03896124, -0.04895062, -0.03117103, ..., -0.08805543,
#          -0.00159268, -0.01874681],
#         [-0.07295442, -0.10007075, -0.04426598, ...,  0.0984863 ,
#          -0.03171132, -0.02476164],
#         [ 0.06496012,  0.06167958, -0.02200151, ...,  0.09671002,
#           0.06404396,  0.07764756],
#         ...,
#         [ 0.01942857, -0.05931739, -0.05637715, ...,  0.01859951,
#           0.04073557,  0.06690883],
#         [ 0.03158224, -0.11798599,  0.04992157, ..., -0.01922568,
#           0.08471431,  0.05000109],
#         [ 0.06081449,  0.02098728, -0.04816774, ..., -0.07291784,
#          -0.06506492,  0.02868169]]), array([[-0.19681614,  0.90950289, -2.9400007 , ..., -1.62777177,
# ...

# %%
K, W, S = sklearn.decomposition.fastica(data['train'].images, whiten=False, tol=.1)
